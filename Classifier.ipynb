# %% [markdown]
# # Genre Feature Classification

# %%
# !pip3 install sklearn
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: sklearn in /opt/homebrew/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.9/site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.8.0)
# Requirement already satisfied: numpy>=1.14.6 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.22.3)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/homebrew/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
# Data Cleaning
set_1 = ["reggae", "metal", "hiphop", "disco", "classical"]
set_2 = ["pop", "jazz", "country", "rock", "blues"]
features = ["spectral_centroid", "rolloff", "zecr", "flux"]
stats = ["mean", "sd"]
frames = [0.5, 1, 3]

# %%
dict_mean_s1 = {}
dict_sd_s1 = {}

for frame in frames:
    dict_mean_s1[frame] = {}
    dict_mean_s1[frame] = {}
    if 'set' not in dict_mean_s1[frame]:
        dict_mean_s1[frame]['set'] = ([0] * 100)
        dict_mean_s1[frame]['set'].extend([1] * 100)
        dict_mean_s1[frame]['set'].extend([2] * 100)
        dict_mean_s1[frame]['set'].extend([3] * 100)
        dict_mean_s1[frame]['set'].extend([4] * 100)
    for f in features:
        dict_mean_s1[frame][f] = []
        for s in set_1:
            filename = s + "_" + f + "_mean_frame_" + str(int(frame*1000))
            # Read set1_data/filename csv with hardcoded column names
            df = pd.read_csv("set1_data/" + filename, names=[str(i) for i in range(1, 101)])
            # convert to numpy array
            df = list(df.values[0])
            # append all values to list
            dict_mean_s1[frame][f].extend(df)            

for frame in frames:
    dict_sd_s1[frame] = {}
    if 'set' not in dict_sd_s1[frame]:
        dict_sd_s1[frame]['set'] = ([0] * 100)
        dict_sd_s1[frame]['set'].extend([1] * 100)
        dict_sd_s1[frame]['set'].extend([2] * 100)
        dict_sd_s1[frame]['set'].extend([3] * 100)
        dict_sd_s1[frame]['set'].extend([4] * 100)
    # list of 100 0's, 100 1's, 100 2's and 100 3's
    for f in features:
        dict_sd_s1[frame][f] = []
        for s in set_1:
            filename = s + "_" + f + "_sd_frame_" + str(int(frame*1000))
            # Read set1_data/filename csv with hardcoded column names
            df = pd.read_csv("set1_data/" + filename, names=[str(i) for i in range(1, 101)])
            # convert to numpy array
            df = list(df.values[0])
            # append all values to list
            dict_sd_s1[frame][f].extend(df)

# %%
dict_mean_s2 = {}
dict_sd_s2 = {}

for frame in frames:
    dict_mean_s2[frame] = {}
    dict_mean_s2[frame] = {}
    if 'set' not in dict_mean_s2[frame]:
        dict_mean_s2[frame]['set'] = ([0] * 100)
        dict_mean_s2[frame]['set'].extend([1] * 100)
        dict_mean_s2[frame]['set'].extend([2] * 100)
        dict_mean_s2[frame]['set'].extend([3] * 100)
        dict_mean_s2[frame]['set'].extend([4] * 100)
    for f in features:
        dict_mean_s2[frame][f] = []
        for s in set_2:
            filename = s + "_" + f + "_mean_frame_" + str(int(frame*1000))
            # Read set2_data/filename csv with hardcoded column names
            df = pd.read_csv("set2_data/" + filename, names=[str(i) for i in range(1, 101)])
            # convert to numpy array
            df = list(df.values[0])
            # append all values to list
            dict_mean_s2[frame][f].extend(df)            

for frame in frames:
    dict_sd_s2[frame] = {}
    if 'set' not in dict_sd_s2[frame]:
        dict_sd_s2[frame]['set'] = ([0] * 100)
        dict_sd_s2[frame]['set'].extend([1] * 100)
        dict_sd_s2[frame]['set'].extend([2] * 100)
        dict_sd_s2[frame]['set'].extend([3] * 100)
        dict_sd_s2[frame]['set'].extend([4] * 100)
    # list of 100 0's, 100 1's, 100 2's and 100 3's
    for f in features:
        dict_sd_s2[frame][f] = []
        for s in set_2:
            filename = s + "_" + f + "_sd_frame_" + str(int(frame*1000))
            # Read set2_data/filename csv with hardcoded column names
            df = pd.read_csv("set2_data/" + filename, names=[str(i) for i in range(1, 101)])
            # convert to numpy array
            df = list(df.values[0])
            # append all values to list
            dict_sd_s2[frame][f].extend(df)

# %%
df_mean_05 = pd.DataFrame.from_dict(dict_mean_s2[0.5])
df_mean_1 = pd.DataFrame.from_dict(dict_mean_s2[1])
df_mean_3 = pd.DataFrame.from_dict(dict_mean_s2[3])
df_sd_05 = pd.DataFrame.from_dict(dict_sd_s2[0.5])
df_sd_1 = pd.DataFrame.from_dict(dict_sd_s2[1])
df_sd_3 = pd.DataFrame.from_dict(dict_sd_s2[3])

# %%
df1_mean_05 = pd.DataFrame.from_dict(dict_mean_s1[0.5])
df1_mean_1 = pd.DataFrame.from_dict(dict_mean_s1[1])
df1_mean_3 = pd.DataFrame.from_dict(dict_mean_s1[3])
df1_sd_05 = pd.DataFrame.from_dict(dict_sd_s1[0.5])
df1_sd_1 = pd.DataFrame.from_dict(dict_sd_s1[1])
df1_sd_3 = pd.DataFrame.from_dict(dict_sd_s1[3])

# %%
# Writing all to csv
df_mean_05.to_csv("data/set2_mean_0_5.csv")
df_mean_1.to_csv("data/set2_mean_1.csv")
df_mean_3.to_csv("data/set2_mean_3.csv")
df_sd_05.to_csv("data/set2_sd_0_5.csv")
df_sd_1.to_csv("data/set2_sd_1.csv")
df_sd_3.to_csv("data/set2_sd_3.csv")

# %%
df1_mean_05.to_csv("data/set1_mean_0_5.csv")
df1_mean_1.to_csv("data/set1_mean_1.csv")
df1_mean_3.to_csv("data/set1_mean_3.csv")
df1_sd_05.to_csv("data/set1_sd_0_5.csv")
df1_sd_1.to_csv("data/set1_sd_1.csv")
df1_sd_3.to_csv("data/set1_sd_3.csv")

# %%
df_mean_05
# Out:
#      set  spectral_centroid  rolloff     zecr    flux
# 0      0             3125.8   7463.6  1429.30  30.429
# 1      0             3426.8   7606.9  1648.20  43.703
# 2      0             2943.0   6983.7  1307.00  34.820
# 3      0             1667.4   3319.7   929.68  20.608
# 4      0             2631.6   5677.7  1398.70  33.714
# ..   ...                ...      ...      ...     ...
# 495    4             1295.9   2481.7   626.30  26.698
# 496    4             1039.4   1721.2   506.73   6.734
# 497    4             1122.3   2270.9   480.15  26.844
# 498    4             2270.3   4723.2  1453.70  23.048
# 499    4             1472.5   2907.8   834.36  16.585
#
# [500 rows x 5 columns]

# %%
df1_mean_05
# Out:
#      set  spectral_centroid  rolloff     zecr     flux
# 0      0             1951.5   4267.0  1071.60  13.7330
# 1      0             1518.8   3212.7   707.20  11.9490
# 2      0             1636.6   3425.9   820.57  14.8520
# 3      0             1768.7   3789.5   923.58  12.0460
# 4      0             1866.9   3941.5   933.09  15.3250
# ..   ...                ...      ...      ...      ...
# 495    4             1771.3   3272.0  1392.30   1.7832
# 496    4             1849.2   3407.9  1330.20   7.3157
# 497    4             1433.1   2591.6   922.92   4.0608
# 498    4             1863.1   3565.4  1345.40   3.5861
# 499    4             1492.3   3152.1   878.35   1.6385
#
# [500 rows x 5 columns]

# %%
# df_mean_05 has 100 rows and 5 columns
# Run classification taking 2 features at a time

import numpy as np
import itertools
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Create all possible combinations of features
flist = []
for i in range(1, len(features)+1):
    for subset in itertools.combinations(features, i):
        flist.append(list(subset))

def run_knn(df):
    # Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(df.drop('set', axis=1), df['set'], test_size=0.2, random_state=42)

    for f_columns in flist:
        # Create KNN classifier
        knn = KNeighborsClassifier()
        knn.fit(X_train[f_columns], y_train)

        # Predict the response for test dataset
        y_pred = knn.predict(X_test[f_columns])

        # Model Accuracy, how often is the classifier correct?
        # print features used and accuracy
        print("Accuracy: ", "{:.2f}".format(accuracy_score(y_test, y_pred)), ", KNN: Features: ", f_columns, ", Accuracy: ", accuracy_score(y_test, y_pred))

        # print("Accuracy:", accuracy_score(y_test[f_columns], y_pred))

def run_svc(df):
    # Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(df.drop('set', axis=1), df['set'], test_size=0.2, random_state=42)

    for f_columns in flist:
        # Create svc classifier
        svc = SVC(kernel='linear', C = 1.0) 
        svc.fit(X_train[f_columns], y_train)

        # Predict the response for test dataset
        y_pred = svc.predict(X_test[f_columns])
        print("Accuracy: ", "{:.2f}".format(accuracy_score(y_test, y_pred)), ", SVC: Features: ", f_columns)


def run_randomforest(df):
    # Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(df.drop('set', axis=1), df['set'], test_size=0.2, random_state=42)

    for f_columns in flist:
        # Create random forest classifier
        rf = RandomForestClassifier(n_estimators=100)
        rf.fit(X_train[f_columns], y_train)

        # Predict the response for test dataset
        y_pred = rf.predict(X_test[f_columns])
        print("Accuracy: ", "{:.2f}".format(accuracy_score(y_test, y_pred)), ", Random Forest: Features: ", f_columns)

def run_mlp(df):
    # Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(df.drop('set', axis=1), df['set'], test_size=0.2, random_state=42)

    for f_columns in flist:
        # Create MLP classifier
        mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000)
        mlp.fit(X_train[f_columns], y_train)

        # Predict the response for test dataset
        y_pred = mlp.predict(X_test[f_columns])
        print("Accuracy: ", "{:.2f}".format(accuracy_score(y_test, y_pred)), ", MLP: Features: ", f_columns)

def run_nb(df):
    # Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(df.drop('set', axis=1), df['set'], test_size=0.2, random_state=42)

    for f_columns in flist:
        # Create Naive Bayes classifier
        nb = GaussianNB()
        nb.fit(X_train[f_columns], y_train)

        # Predict the response for test dataset
        y_pred = nb.predict(X_test[f_columns])
        print("Accuracy: ", "{:.2f}".format(accuracy_score(y_test, y_pred)), ", Naive Bayes: Features: ", f_columns)

# %%
flist
# Out:
# [['spectral_centroid'],
#  ['rolloff'],
#  ['zecr'],
#  ['flux'],
#  ['spectral_centroid', 'rolloff'],
#  ['spectral_centroid', 'zecr'],
#  ['spectral_centroid', 'flux'],
#  ['rolloff', 'zecr'],
#  ['rolloff', 'flux'],
#  ['zecr', 'flux'],
#  ['spectral_centroid', 'rolloff', 'zecr'],
#  ['spectral_centroid', 'rolloff', 'flux'],
#  ['spectral_centroid', 'zecr', 'flux'],
#  ['rolloff', 'zecr', 'flux'],
#  ['spectral_centroid', 'rolloff', 'zecr', 'flux']]

# %%
# run_knn(df_mean_05)
# run_svc(df_mean_05)
# run_randomforest(df_mean_05)
# run_mlp(df_mean_05)
# run_nb(df_mean_05)

# %% [markdown]
# # Set 1

# %% [markdown]
# ## With 0.5 frame

# %%
print("Mean")
run_nb(df1_mean_05)
run_mlp(df1_mean_05)
run_randomforest(df1_mean_05)
run_svc(df1_mean_05)
run_knn(df1_mean_05)

print("SD")
run_nb(df1_sd_05)
run_mlp(df1_sd_05)
run_randomforest(df1_sd_05)
run_svc(df1_sd_05)
run_knn(df1_sd_05)
# Out:
# Mean
# Accuracy:  0.49 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.47 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.43 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.56 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.49 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.49 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.61 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.57 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.55 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.55 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.55 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.58 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.60 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.68 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.66 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.10 , MLP: Features:  ['spectral_centroid']
# Accuracy:  0.14 , MLP: Features:  ['rolloff']
# Accuracy:  0.24 , MLP: Features:  ['zecr']
# Accuracy:  0.56 , MLP: Features:  ['flux']
# Accuracy:  0.12 , MLP: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.23 , MLP: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.33 , MLP: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.37 , MLP: Features:  ['rolloff', 'zecr']
# Accuracy:  0.30 , MLP: Features:  ['rolloff', 'flux']
# Accuracy:  0.39 , MLP: Features:  ['zecr', 'flux']
# Accuracy:  0.46 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.43 , MLP: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.38 , MLP: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.44 , MLP: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.53 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.35 , Random Forest: Features:  ['spectral_centroid']
# Accuracy:  0.43 , Random Forest: Features:  ['rolloff']
# Accuracy:  0.32 , Random Forest: Features:  ['zecr']
# Accuracy:  0.54 , Random Forest: Features:  ['flux']
# Accuracy:  0.46 , Random Forest: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.44 , Random Forest: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.59 , Random Forest: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.51 , Random Forest: Features:  ['rolloff', 'zecr']
# Accuracy:  0.63 , Random Forest: Features:  ['rolloff', 'flux']
# Accuracy:  0.68 , Random Forest: Features:  ['zecr', 'flux']
# Accuracy:  0.50 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.58 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.57 , Random Forest: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.63 , Random Forest: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.61 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.54 , SVC: Features:  ['spectral_centroid']
# Accuracy:  0.44 , SVC: Features:  ['rolloff']
# Accuracy:  0.42 , SVC: Features:  ['zecr']
# Accuracy:  0.55 , SVC: Features:  ['flux']
# Accuracy:  0.57 , SVC: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.60 , SVC: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.58 , SVC: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.54 , SVC: Features:  ['rolloff', 'zecr']
# Accuracy:  0.48 , SVC: Features:  ['rolloff', 'flux']
# Accuracy:  0.63 , SVC: Features:  ['zecr', 'flux']
# Accuracy:  0.55 , SVC: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.62 , SVC: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.65 , SVC: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.63 , SVC: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.63 , SVC: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.38 , KNN: Features:  ['spectral_centroid'] , Accuracy:  0.38
# Accuracy:  0.48 , KNN: Features:  ['rolloff'] , Accuracy:  0.48
# Accuracy:  0.35 , KNN: Features:  ['zecr'] , Accuracy:  0.35
# Accuracy:  0.49 , KNN: Features:  ['flux'] , Accuracy:  0.49
# Accuracy:  0.48 , KNN: Features:  ['spectral_centroid', 'rolloff'] , Accuracy:  0.48
# Accuracy:  0.56 , KNN: Features:  ['spectral_centroid', 'zecr'] , Accuracy:  0.56
# Accuracy:  0.38 , KNN: Features:  ['spectral_centroid', 'flux'] , Accuracy:  0.38
# Accuracy:  0.55 , KNN: Features:  ['rolloff', 'zecr'] , Accuracy:  0.55
# Accuracy:  0.47 , KNN: Features:  ['rolloff', 'flux'] , Accuracy:  0.47
# Accuracy:  0.46 , KNN: Features:  ['zecr', 'flux'] , Accuracy:  0.46
# Accuracy:  0.56 , KNN: Features:  ['spectral_centroid', 'rolloff', 'zecr'] , Accuracy:  0.56
# Accuracy:  0.49 , KNN: Features:  ['spectral_centroid', 'rolloff', 'flux'] , Accuracy:  0.49
# Accuracy:  0.58 , KNN: Features:  ['spectral_centroid', 'zecr', 'flux'] , Accuracy:  0.58
# Accuracy:  0.55 , KNN: Features:  ['rolloff', 'zecr', 'flux'] , Accuracy:  0.55
# Accuracy:  0.56 , KNN: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux'] , Accuracy:  0.56
# SD
# Accuracy:  0.25 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.27 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.18 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.35 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.29 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.27 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.36 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.31 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.35 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.38 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.30 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.33 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.37 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.36 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.34 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.12 , MLP: Features:  ['spectral_centroid']
# Accuracy:  0.24 , MLP: Features:  ['rolloff']
# Accuracy:  0.15 , MLP: Features:  ['zecr']
# Accuracy:  0.38 , MLP: Features:  ['flux']
# Accuracy:  0.11 , MLP: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.22 , MLP: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.27 , MLP: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.17 , MLP: Features:  ['rolloff', 'zecr']
# Accuracy:  0.34 , MLP: Features:  ['rolloff', 'flux']
# Accuracy:  0.17 , MLP: Features:  ['zecr', 'flux']
# Accuracy:  0.25 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.25 , MLP: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.28 , MLP: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.17 , MLP: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.21 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.16 , Random Forest: Features:  ['spectral_centroid']
# Accuracy:  0.22 , Random Forest: Features:  ['rolloff']
# Accuracy:  0.26 , Random Forest: Features:  ['zecr']
# Accuracy:  0.23 , Random Forest: Features:  ['flux']
# Accuracy:  0.27 , Random Forest: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.26 , Random Forest: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.37 , Random Forest: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.23 , Random Forest: Features:  ['rolloff', 'zecr']
# Accuracy:  0.32 , Random Forest: Features:  ['rolloff', 'flux']
# Accuracy:  0.34 , Random Forest: Features:  ['zecr', 'flux']
# Accuracy:  0.23 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.37 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.37 , Random Forest: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.39 , Random Forest: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.33 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.18 , SVC: Features:  ['spectral_centroid']

# %% [markdown]
# # With 1 Frame

# %%
print("Mean")
run_nb(df1_mean_1)
run_mlp(df1_mean_1)
run_randomforest(df1_mean_1)
run_svc(df1_mean_1)
run_knn(df1_mean_1)

print("SD")
run_nb(df1_sd_1)
run_mlp(df1_sd_1)
run_randomforest(df1_sd_1)
run_svc(df1_sd_1)
run_knn(df1_sd_1)

# %% [markdown]
# ## With 3 Frame

# %%
print("Mean")
run_nb(df1_mean_3)
run_mlp(df1_mean_3)
run_randomforest(df1_mean_3)
run_svc(df1_mean_3)
run_knn(df1_mean_3)

print("SD")
run_nb(df1_sd_3)
run_mlp(df1_sd_3)
run_randomforest(df1_sd_3)
run_svc(df1_sd_3)
run_knn(df1_sd_3)

# %% [markdown]
# # Set 2

# %% [markdown]
# ## With 0.5 frame

# %%
print("Mean")
run_nb(df_mean_05)
run_mlp(df_mean_05)
run_randomforest(df_mean_05)
run_nb(df_mean_05)
run_nb(df_mean_05)

print("SD")
run_nb(df_sd_05)
run_mlp(df_sd_05)
run_randomforest(df_sd_05)
run_svc(df_sd_05)
run_knn(df_sd_05)

# %% [markdown]
# # With 1 Frame

# %%
print("Mean")
run_nb(df_mean_1)
run_mlp(df_mean_1)
run_randomforest(df_mean_1)
run_svc(df_mean_1)
run_knn(df_mean_1)

print("SD")
run_nb(df_sd_1)
run_mlp(df_sd_1)
run_randomforest(df_sd_1)
run_svc(df_sd_1)
run_knn(df_sd_1)
# Out:
# Mean
# Accuracy:  0.47 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.42 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.33 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.42 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.51 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.37 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.52 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.41 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.53 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.46 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.48 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.50 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.28 , MLP: Features:  ['spectral_centroid']
# Accuracy:  0.10 , MLP: Features:  ['rolloff']
# Accuracy:  0.15 , MLP: Features:  ['zecr']
# Accuracy:  0.42 , MLP: Features:  ['flux']
# Accuracy:  0.34 , MLP: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.40 , MLP: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.28 , MLP: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.27 , MLP: Features:  ['rolloff', 'zecr']
# Accuracy:  0.24 , MLP: Features:  ['rolloff', 'flux']
# Accuracy:  0.39 , MLP: Features:  ['zecr', 'flux']
# Accuracy:  0.27 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.21 , MLP: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.24 , MLP: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.10 , MLP: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.13 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.38 , Random Forest: Features:  ['spectral_centroid']
# Accuracy:  0.40 , Random Forest: Features:  ['rolloff']
# Accuracy:  0.30 , Random Forest: Features:  ['zecr']
# Accuracy:  0.34 , Random Forest: Features:  ['flux']
# Accuracy:  0.47 , Random Forest: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.48 , Random Forest: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.51 , Random Forest: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.49 , Random Forest: Features:  ['rolloff', 'zecr']
# Accuracy:  0.54 , Random Forest: Features:  ['rolloff', 'flux']
# Accuracy:  0.43 , Random Forest: Features:  ['zecr', 'flux']
# Accuracy:  0.51 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.58 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.54 , Random Forest: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.57 , Random Forest: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.60 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.47 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.42 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.33 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.42 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.51 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.37 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.52 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.41 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.53 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.46 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.48 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.50 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.47 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.42 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.33 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.42 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.51 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.37 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.52 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.41 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.53 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.46 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.48 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.50 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.53 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# SD
# Accuracy:  0.26 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.32 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.29 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.29 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.29 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.25 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.38 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.28 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.40 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.35 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.29 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.38 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.30 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.32 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.30 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.29 , MLP: Features:  ['spectral_centroid']
# Accuracy:  0.18 , MLP: Features:  ['rolloff']
# Accuracy:  0.12 , MLP: Features:  ['zecr']
# Accuracy:  0.31 , MLP: Features:  ['flux']
# Accuracy:  0.32 , MLP: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.29 , MLP: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.42 , MLP: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.22 , MLP: Features:  ['rolloff', 'zecr']
# Accuracy:  0.33 , MLP: Features:  ['rolloff', 'flux']
# Accuracy:  0.38 , MLP: Features:  ['zecr', 'flux']
# Accuracy:  0.19 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.33 , MLP: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.31 , MLP: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.35 , MLP: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.23 , MLP: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.34 , Random Forest: Features:  ['spectral_centroid']
# Accuracy:  0.25 , Random Forest: Features:  ['rolloff']
# Accuracy:  0.19 , Random Forest: Features:  ['zecr']
# Accuracy:  0.28 , Random Forest: Features:  ['flux']
# Accuracy:  0.41 , Random Forest: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.34 , Random Forest: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.46 , Random Forest: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.32 , Random Forest: Features:  ['rolloff', 'zecr']
# Accuracy:  0.41 , Random Forest: Features:  ['rolloff', 'flux']
# Accuracy:  0.38 , Random Forest: Features:  ['zecr', 'flux']
# Accuracy:  0.45 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.51 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.52 , Random Forest: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.45 , Random Forest: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.50 , Random Forest: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.26 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.32 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.29 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.29 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.29 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.25 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.38 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.28 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.40 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.35 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.29 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.38 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.30 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.32 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.30 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']
# Accuracy:  0.26 , Naive Bayes: Features:  ['spectral_centroid']
# Accuracy:  0.32 , Naive Bayes: Features:  ['rolloff']
# Accuracy:  0.29 , Naive Bayes: Features:  ['zecr']
# Accuracy:  0.29 , Naive Bayes: Features:  ['flux']
# Accuracy:  0.29 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff']
# Accuracy:  0.25 , Naive Bayes: Features:  ['spectral_centroid', 'zecr']
# Accuracy:  0.38 , Naive Bayes: Features:  ['spectral_centroid', 'flux']
# Accuracy:  0.28 , Naive Bayes: Features:  ['rolloff', 'zecr']
# Accuracy:  0.40 , Naive Bayes: Features:  ['rolloff', 'flux']
# Accuracy:  0.35 , Naive Bayes: Features:  ['zecr', 'flux']
# Accuracy:  0.29 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr']
# Accuracy:  0.38 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'flux']
# Accuracy:  0.30 , Naive Bayes: Features:  ['spectral_centroid', 'zecr', 'flux']
# Accuracy:  0.32 , Naive Bayes: Features:  ['rolloff', 'zecr', 'flux']
# Accuracy:  0.30 , Naive Bayes: Features:  ['spectral_centroid', 'rolloff', 'zecr', 'flux']

# %% [markdown]
# ## With 3 Frame

# %%
print("Mean")
run_nb(df_mean_3)
run_mlp(df_mean_3)
run_randomforest(df_mean_3)
run_svc(df_mean_3)
run_knn(df_mean_3)

print("SD")
run_nb(df_sd_3)
run_mlp(df_sd_3)
run_randomforest(df_sd_3)
run_svc(df_sd_3)
run_knn(df_sd_3)
